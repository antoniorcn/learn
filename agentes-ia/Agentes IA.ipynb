# %%
# !pip install -q langchain

# %%
# !pip install -q langchain-google-genai google-generativeai
# Out:
#   WARNING: The script filetype.exe is installed in 'C:\Users\anton\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\anton\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os

# %%
APIKEY=os.environ.get("GEMINI_APIKEY")
APIKEY
