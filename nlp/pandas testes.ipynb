# %%
import pandas as pd

# %%
salarios = pd.read_csv("Salaries.csv", dtype={
    "Id": int, 
    "EmployeeName": str, 
    "JobTitle": str, 
    "BasePay": float, 
    "OvertimePay": float, 
    "OtherPay": float, 
    "Benefits": float, 
    "TotalPay": float, 
    "TotalPayBenefits": float, 
    "Year": int, 
    "Notes": str, 
    "Agency": str, 
    "Status": str})
salarios
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148646  148648     Joann Anderson
# 148647  148649        Leon Walker
# 148648  148650      Roy I Tillery
# 148649  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148645                       Human Services Technician       0.00
# ...

# %%
cargos = salarios.groupby(["JobTitle"])
# Out:
#             Id           EmployeeName  \
# 0            1         NATHANIEL FORD
# 1            2           GARY JIMENEZ
# 2            3         ALBERT PARDINI
# 3            4      CHRISTOPHER CHONG
# 4            5        PATRICK GARDNER
# ...        ...                    ...
# 146093  146094            Swati Pande
# 146498  146499        Donald R Maffei
# 147040  147041  Christopher W Manners
# 147293  147294        Miao Hong Huang
# 147887  147888          George M Rush
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %%
cargos[["TotalPay"]].mean()
# Out:
#                                                     TotalPay
# JobTitle
# ACCOUNT CLERK                                   44035.664337
# ACCOUNTANT                                      47429.268000
# ACCOUNTANT INTERN                               29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000
# ACUPUNCTURIST                                   67594.400000
# ...                                                      ...
# X-RAY LABORATORY AIDE                           52705.880385
# X-Ray Laboratory Aide                           50823.942700
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.870000
# Youth Comm Advisor                              41414.307500
# ZOO CURATOR                                     66686.560000
#
# [2159 rows x 1 columns]
